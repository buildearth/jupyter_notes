# %% [markdown]
# # pycharm启动scrapy项目

# %% [markdown]
# 1. 在项目的根目录创建一个文件runner.py
# ```python
# from scrapy.cmdline import execute
# execute("scrapy crawl baidu".split())  # baidu是爬虫的名字(scrapy genspider baidu baidu.com)
# ```
# 2.右键执行这个文件，就能启动scrapy项目

# %% [markdown]
# # 中间件

# %% [markdown]
# scrapy中的中间件只有两个：
# - engine 和下载器之间是：下载器中间件
# - engine 和爬虫之间是：spider中间件
#
# 常用的是下载器中间件，爬虫中间件用的很少很少。

# %% [markdown]
# 中间件主要是对请求和响应的过程中，多两者做进一步的加工处理，如添加代理。

# %% [markdown]
# ## 下载器中间件

# %% [markdown]
# 中间件是项目中的`middlewares.py`文件，会对请求对象或响应对象进行拦截，做进一步的加工和处理，然后再决定其走向。

# %% [markdown]
# 下载器中间件的类中有5个方法，需要的就留着. 不需要可以删掉。
#
# 具体看看每个方法的作用

# %% [markdown]
# **from_crawler**

# %% [markdown]
# 函数的作用是，给爬虫绑定一些信号，当信号触发时，自动的执行一些方法。就好比烟雾报警器，当有人抽烟时，就会触发报警信号，自动喷水灭火。
#
# 比较常用的是在爬虫开始运行时绑定一些动作，在爬虫结束时绑定一些动作。

# %% [markdown]
# ```python
# @classmethod
# def from_crawler(cls, crawler):
#     # This method is used by Scrapy to create your spiders.
#     s = cls()  # 创建当前类的对象 -> 理解成每个函数中的self就可以了
#     crawler.signals.connect(s.spider_opened, signal=signals.spider_opened)  # 爬虫开始运行的信号，绑定了s.spider_opened方法，当爬虫运启动时，自动执行该方法
#     return s
# ```

# %% [markdown]
# 细心的就会发现该类中有spider_opened函数，就打印了一行log
# ```python
#     def spider_opened(self, spider):
#         spider.logger.info('Spider opened: %s' % spider.name)
# ```

# %% [markdown]
# 其内置的信号有：
# ![image.png](attachment:image.png)

# %% [markdown]
# 绑定一些信号来看看效果
# 1. middlewares.py文件
# ```python
# class ZhongDownloaderMiddleware:
#     @classmethod
#     def from_crawler(cls, crawler):
#         # This method is used by Scrapy to create your spiders.
#         s = cls()
#         crawler.signals.connect(s.spider_opened, signal=signals.spider_opened)  # 爬虫启动信号绑定
#         crawler.signals.connect(s.spider_closed, signal=signals.spider_closed)  # 爬虫结束信号绑定
#         return s
#
#     def spider_opened(self, spider):
#         print('Spider opened: %s' % spider.name)
#
#     def spider_closed(self, spider):
#         print('Spider opened: %s' % spider.name)
#
# ```

# %% [markdown]
# 2. settings.py文件, 打开中间件的配置
#
# ```python
# BOT_NAME = 'zhong'
#
# SPIDER_MODULES = ['zhong.spiders']
# NEWSPIDER_MODULE = 'zhong.spiders'
# LOG_LEVEL = 'WARNING'
#
#
# # Crawl responsibly by identifying yourself (and your website) on the user-agent
# USER_AGENT = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"
#
# # Obey robots.txt rules
# ROBOTSTXT_OBEY = False
#
# # Enable or disable downloader middlewares
# # See https://docs.scrapy.org/en/latest/topics/downloader-middleware.html
# DOWNLOADER_MIDDLEWARES = {
#    'zhong.middlewares.ZhongDownloaderMiddleware': 543,
# }
#
# ```

# %% [markdown]
# 3. 项目个根目录创建runner文件
# ![image.png](attachment:image.png)
# ```python
# from scrapy.cmdline import execute
# execute("scrapy crawl baidu".split())
# ```

# %% [markdown]
# 4.启动爬虫
# ![image.png](attachment:image.png)

# %% [markdown]
# **process_request**

# %% [markdown]
# 处理请求的,请求在发送给下载器的时候. 自动执行的函数，在该函数中可以对请求拦截下来，做处理。

# %% [markdown]
# ```python
#     def process_request(self, request, spider):  # request是当前请求对象
#         # Called for each request that goes through the downloader
#         # middleware.
#
#         # Must either:
#         # - return None: continue processing this request
#         # - or return a Response object
#         # - or return a Request object
#         # - or raise IgnoreRequest: process_exception() methods of
#         #   installed downloader middleware will be called
#         return None
# ```

# %% [markdown]
# 这个方法限制了返回值，必须是给定的某一个：
# - return None  请求继续向下一个下载器中间件走，最终走到下载器
# - return Response obj 停下来. 这个请求就不会走下载器, 而是直接把响应对象给到引擎，然后给到爬虫
# - return Request obj 停下来.这个请求也不会走下载器. 而是直接把请求对象给到引擎，然后到调度器进行去重，加入队列
# - 抛出异常，会执行process_exception方法

# %% [markdown]
# 中间件有优先级，其数字越小优先级越高，数字小的离引擎近，请求时从engine到下载器，经过中间件时，按数字由小到大，即离引擎近中间件的process_request方法先经过。

# %% [markdown]
# **process_response**

# %% [markdown]
# 在响应对象反馈给引擎的时候自动执行, 可以判断各种状态码. 判断返回的数据是否正常

# %% [markdown]
# ```python
#     def process_response(self, request, response, spider):
#         # Called with the response returned from the downloader.
#
#         # Must either;
#         # - return a Response object
#         # - return a Request object
#         # - or raise IgnoreRequest
#         return response
# ```

# %% [markdown]
# 这个方法限制了返回值，必须是给定的某一个：
# - return a Response obj  把响应对象返回, 继续往回走, 走下一个中间件，最后走到engine
# - return a Request obj  返回一个请求对象,直接把请求对象发给引擎(跳过后续的中间件), 引擎继续走调度器、去重、加入队列
# - 抛出异常，会执行process_exception方法

# %% [markdown]
#  从下载器到engine，数字越大离下载器越近，按数字由大到小经过中间件的process_response方法，即离下载器近的先经过。

# %% [markdown]
# **process_exception**

# %% [markdown]
# 这个没啥说的，就是在process_request和process_response方法抛出异常时会调用这个函数，一般也就用来打印log。

# %% [markdown]
# ## 下载器中间件的简单使用

# %% [markdown]
# 下载器中间件代码修改，加上一些打印
# ```python
# class ZhongDownloaderMiddleware:
#     @classmethod
#     def from_crawler(cls, crawler):
#         # This method is used by Scrapy to create your spiders.
#         s = cls()
#         crawler.signals.connect(s.spider_opened, signal=signals.spider_opened)  # 爬虫启动信号绑定
#         crawler.signals.connect(s.spider_closed, signal=signals.spider_closed)  # 爬虫结束信号绑定
#         return s
#
#     def process_request(self, request, spider):
#         print("我是请求来的", request.url)
#         return None
#
#     def process_response(self, request, response, spider):
#         print("我是下载器来的", response.url)
#         return response
#
#     def process_exception(self, request, exception, spider):
#         pass
#
#     def spider_opened(self, spider):
#         print('Spider opened: %s' % spider.name)
#
#     def spider_closed(self, spider):
#         print('Spider opened: %s' % spider.name)
#
# ```
# 在爬虫代码中打印
# ```python
# class BaiduSpider(scrapy.Spider):
#     name = 'baidu'
#     allowed_domains = ['baidu.com']
#     start_urls = ['http://www.baidu.com/']
#
#     def parse(self, resp, **kwargs):
#         print(resp.url)  # 打印访问到的页面的url
# ```

# %% [markdown]
# 执行结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 会发现和预想的不一样，process_request的打印输出了两次。
#
# 其原因是，百度的服务器重定向了，scrapy有一个处理重定向的中间件，会处理重定向的响应：
# - 仔细观察两次process_request打印的url，第一个是http，第二个是https，这是百度服务器的行为
# - scrapy处理处理重定向的中间件数字是790，我们的中间件数字是543，所以先经过了scrapy中间件
# - scrapy中间件的process_response，检测到有重定向，就会返回一个Request对象
# - 在process_response方法中返回一个Request对象，意味着后续的中间件不会再经过，直接将Request对象给引擎，再到调度器。
#
# 所以出现了上图的效果，如果我们把`ZhongDownloaderMiddleware`的数字设置为791，就会打印我们预想的结果
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 下载器中间件的用途

# %% [markdown]
# 当每次请求都要做处理时，就可以使用中间件。

# %% [markdown]
# **1.随机选择User Agent**

# %% [markdown]
# User Agent大全：`http://useragentstring.com/pages/useragentstring.php?name=Chrome`
#
# 可以从上面网址中，随机选择几个，在每次请求发送时随机更换UA。

# %% [markdown]
# 在setting.py文件中配置一些UA
# ```python
# User_Agents = [
#     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.84 Safari/537.36",
#     "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36",
#     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:101.0) Gecko/20100101 Firefox/101.0",
#     "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:99.0) Gecko/20100101 Firefox/99.0"
# ]
# ```

# %% [markdown]
# 在下载器中为每个请求配置UA
# ```python
# class ZhongDownloaderMiddleware:
#     def process_request(self, request, spider):
#         ua = random.choice(User_Agents)
#         request.headers["User_Agent"] = ua
#         return None
# ```

# %% [markdown]
# 在爬虫中打印请求头信息
# ```python
# class BaiduSpider(scrapy.Spider):
#     name = 'baidu'
#     allowed_domains = ['baidu.com']
#     start_urls = ['http://www.baidu.com/']
#
#     def parse(self, resp, **kwargs):
#         print(resp.request.headers)  # 打印请求头
# ```

# %% [markdown]
# 效果是每次请求都随机选择一个UA。

# %% [markdown]
# **2.每次请求添加代理**

# %% [markdown]
# 可以结合之前的免费线程池，每次请求随机选择一个代理IP给请求。
# ```python
# # 知道代理Ip时，添加代理方式
# request.meta['proxy'] = "http://proxy.yourproxy:8001"
#
# # 如果代理ip有账号密码，就需要再加上下面内容
# # proxy_user_pass = "USERNAME:PASSWORD"
# # encoded_user_pass = base64.encodestring(proxy_user_pass)
# # request.headers['Proxy-Authorization'] = 'Basic ' + encoded_user_pass
#
# ```

# %% [markdown]
# 但是ip直接暴露给用户的方式，有些人会一直使用这一个IP，导致这个IP可用性很差，即使是购买的ip，ip肯定是有多个人同时使用的，有些IP的体验感仍然很差。

# %% [markdown]
# 我们可以购买隧道代理，其不会把IP暴露出来，具体使用哪个ip由服务商确定，所以其体验感相对于IP暴露出来的方式来说会好一点。

# %% [markdown]
# ***scrapy使用隧道代理***：

# %% [markdown]
# 选择快代理的隧道代理，具体使用看其网站的隧道代理使用文档。
# ![image.png](attachment:image.png)
# 查看代码样例
# ![image-2.png](attachment:image-2.png)
# 找到scrapy的样例代码
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 上图中的proxy username password在
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# 代码实现：
# ```python
# class ZhongDownloaderMiddleware:
#     def process_request(self, request, spider):
#         ua = random.choice(User_Agents)
#         request.headers["User_Agent"] = ua
#         proxy = "tps365.kdlapi.com:15818"  # 更换个隧道
#         request.meta['proxy'] = "http://%(proxy)s" % {'proxy': proxy}
#         # 用户名密码认证
#         request.headers['Proxy-Authorization'] = basic_auth_header('t14860877193391', 'kg72z3rb')  # 白名单认证可注释此行
#         request.headers["Connection"] = "close"
#         return None
#
#     def process_response(self, request, response, spider):
#         # 它不对劲的时候。 是不是应该重新发送请求
#         # 可能需要在返回的时候. 做进一步的判断. 判断该次请求是否是理想中的响应体
#         if "百度安全验证" in response.text:  # 被检测出来了，重新发送请求
#             # 回去。 重新发送请求
#             # 不需要去重
#             request.dont_filter = True  # (调度器)不去重，一定要加这个，不然调度器去掉重复就不会重新发送了
#             return request  # 给engine然后再到调度去，dont_filter=True，不会去重，直接加入队列
#         return response
# ```

# %% [markdown]
# ```python
# class BaiduSpider(scrapy.Spider):
#     name = 'baidu'
#     allowed_domains = ['baidu.com']
#     start_urls = ['http://www.baidu.com/s?wd=ip']
#
#     def parse(self, resp, **kwargs):
#         print(resp.text)
# ```

# %% [markdown]
# **scrapy中间件 结合 selenium**

# %% [markdown]
# 当有些网站的有很复杂的反扒措施，我们不想去逆向，就可以结合selenium跳过反扒措施的网页，直接拿到页面的Element。
#
# 或者不想看登录的逆向，可以直接selenium登录。拿到cookie,每次请求的时候添加cookie.

# %% [markdown]
# **实战**

# %% [markdown]
# 网址：https://www.zhipin.com/c101010100/?query=python&page=2&ka=page-2

# %% [markdown]
# 我们所有的请求都是直聘上的，每个请求直聘上都有反爬措施，会有很多请求来验证访问是否合法。
#
# 所以所有的请求都要在中间件中通过selenium模拟访问访问拿到页面的element。

# %% [markdown]
# 爬虫代码：
# ```python
# import scrapy
# class BossSpider(scrapy.Spider):
#     name = 'boss'
#     allowed_domains = ['zhipin.com']
#     start_urls = ['https://www.zhipin.com/c101010100/?query=python&page=2&ka=page-2']
#
#     def parse(self, resp, **kwargs):
#         print(resp.text)
# ```

# %% [markdown]
# 编写下载器中间件：
# ```python
# class ZhipDownloaderMiddleware:
#     # Not all methods need to be defined. If a method is not defined,
#     # scrapy acts as if the downloader middleware does not modify the
#     # passed objects.
#
#     @classmethod
#     def from_crawler(cls, crawler):
#         # This method is used by Scrapy to create your spiders.
#         s = cls()
#         crawler.signals.connect(s.spider_opened, signal=signals.spider_opened)  # 绑定信号和事件
#         crawler.signals.connect(s.spider_closed, signal=signals.spider_closed)
#         return s
#
#     def process_request(self, request, spider):
#         # 使用selenium来完成页面数据（Elements）的获取
#         # print(request.url)
#         self.web = Chrome()  # 程序跑起来之后。 去创建Chrome对象。 程序跑完了之后。 关掉web对象
#         self.web.implicitly_wait(10)  # 软等待
#         self.web.get(request.url)  # 直接访问即可，就是我们要访问的url
#         # 来等待页面加载完成
#         self.web.find_element(By.XPATH, '//*[@id="header"]/div[1]/div[3]/div/a[1]')  # 随便找个东西。如果找到了。就算加载完了
#         # print(self.web.page_source)
#         page_source = self.web.page_source  # 就可以拿elements
#         # 页面源代码有了？ 下载器还去么？
#         # 组装一个响应对象。 返回 -> 引擎即可
#         resp = HtmlResponse(  # 组装响应对象
#             status=200,  # 状态码
#             url=request.url,  # url
#             body=page_source.encode("utf-8"),  # 页面源代码，body中是bytes类型的数据，需要编码
#             request=request  # 请求对象
#         )
#         return resp
#
#     def spider_opened(self, spider):
#         # 爬虫启动时，初始化selenium
#         # 可以加无头，等一些Option配置
#         self.web = Chrome()  # 程序跑起来之后。 去创建Chrome对象。 程序跑完了之后。 关掉web对象
#         self.web.implicitly_wait(10)  # 软等待
#
#     def spider_closed(self, spider):
#         self.web.close()
# ```

# %% [markdown]
# 上述方法中有一个缺点，就是所有的请求都会走selenium的逻辑，当一个url的反爬没有那么厉害时，我们想走普通的scrapy的下载器中间件的逻辑该怎么实现？

# %% [markdown]
# 就得在中间件做判断，判断是走selenium还是下载器逻辑，常规的想法是在Request对象中携带参数(meta中给key和value)，然后在中间件中拿到这个参数来判断是哪种请求。
#
# 这种方法有个弊端，就是要访问的url中的参数和在meta中设置的key的名字是重复了，那么就会传递一个错误的url。

# %% [markdown]
# 采用继承Reqeust对象的方式来区分，在中间件中使用isinstance来判断。

# %% [markdown]
# 1.编写SeleniumRequest对象，自己造一个请求类型
#
# 其用来发送Selenium的请求，走Selenium模拟访问的逻辑，新建一个文件`zhip/zhip/req.py`
# ```python
# from scrapy.http import Request  # scrapy 默认的请求类型
#
#
# class SeleniumRequest(Request):  # 只是类的名字不一样，其他的都是默认的请求对象Request一模一样
#     pass
# ```

# %% [markdown]
# 2.在爬虫代码中根据不同请求来返回不同的对象
# ```python
# import scrapy
# from zhip.req import SeleniumRequest
#
# class BossSpider(scrapy.Spider):
#     name = 'boss'
#     allowed_domains = ['zhipin.com']
#     start_urls = ['https://www.zhipin.com/c101010100/?query=python&page=2&ka=page-2']
#
#     def start_requests(self):
#         # 要用selenium了
#         yield SeleniumRequest(url=self.start_urls[0], dont_filter=True)  # 绕过反爬，用这个请求对象
#         yield scrapy.Request(url=self.start_urls[0], dont_filter=True)  # 普通请求，走下载器
#
#     def parse(self, resp, **kwargs):
#         print(resp.text)
#
# ```

# %% [markdown]
# 3.在中间件中判断走哪个逻辑
# ```python
#     def process_request(self, request, spider):
#         # 是SeleniumRequest对象，使用selenium来完成页面数据（Elements）的获取
#         if isinstance(request, SeleniumRequest):
#             self.web = Chrome()
#             self.web.implicitly_wait(10)
#             self.web.get(request.url)
#             self.web.find_element(By.XPATH, '//*[@id="header"]/div[1]/div[3]/div/a[1]')
#             page_source = self.web.page_source
#
#             resp = HtmlResponse(
#                 status=200,
#                 url=request.url,
#                 body=page_source.encode("utf-8"),
#                 request=request
#             )
#             return resp
#         # 是普通的请求对象，走原逻辑
#         return None
# ```

# %% [markdown]
# ## 爬虫中间件

# %% [markdown]
# 这个用的不多，没啥使用场景，一般就用来看看日志啥的

# %% [markdown]
# # 全站数据爬取-CrawlSpider

# %% [markdown]
# 网址：https://www.che168.com/china/a0_0msdgscncgpi1ltocsp1exx0/
#
# 这个网址是千人千面型的，每个人看到的网址都是不一样，如何找到这个网页?
# 1. 访问 https://www.autohome.com.cn/beijing/
# 2. 点击
# ![image.png](attachment:image.png)
# 3. 点击第二页再点击第一页

# %% [markdown]
# 这个网站使用scrapy，需设置上ua，cookie，延迟下载这几项，否则很快就被其识别了。

# %% [markdown]
# 1. settings.py配置
# 2. 先实现一页的数据分析，不考虑分页
#     - 页面是多个li标签，中有详情页的url

# %% [markdown]
# ## 适用场景

# %% [markdown]
# 适用于分页，数据在详情页中的网址
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 使用

# %% [markdown]
# ### scrapy链接提取器

# %% [markdown]
# 可以直接从response对象中拿到需要的链接

# %% [markdown]
# ```python
# from scrapy.linkextractors import LinkExtractor  # 导包
#
# # 初始化链接提取器的参数
#
# def __init__(
#     self,
#     allow=(),  # 允许，这里给的是正则表达式。在页面中，只要是链接中一些字符处符合正则，都会提取
#     deny=(),  # 不允许，这里给的是正则表达式，在页面中，只要是符合正则的链接不会提取
#     allow_domains=(),  # 允许的域名
#     deny_domains=(),  # 不允许的域名
#     restrict_xpaths=(),  # 用xpath来提取链接的url地址，xpath不是具体的url的提取规则，而是一个范围的提取规则，会拿到该范围下所有的url
#     tags=('a', 'area'),  # 拿的链接是什么标签，一般不会修改
#     attrs=('href',),
#     canonicalize=False,
#     unique=True,
#     process_value=None,
#     deny_extensions=None,
#     restrict_css=(),  # 给出一个css的范围，提取该范围下的所有url
#     strip=True,
#     restrict_text=None,  # 通过文本获取链接
# )
# ```

# %% [markdown]
# 提取汽车之家二手车的车的详情url地址：
# ```python
# import scrapy
# from scrapy.linkextractors import LinkExtractor
#
# class JiaSpider(scrapy.Spider):
#     name = 'jia'
#     allowed_domains = ['che168.com']
#     start_urls = ['https://www.che168.com/nlist/beijing/list/?pvareaid=100533']
#
#     def parse(self, reps, **kwargs):
#         # lks = LinkExtractor(restrict_xpaths='//ul[@class="viewlist_ul"]') # 这两个都可以拿到url
#         lks = LinkExtractor(restrict_xpaths='//ul[@class="viewlist_ul"]/li/a', deny_domains=('topicm.che168.com'))
#         links = lks.extract_links(reps)
#         for link in links:
#             url = link.url
#             text = link.text
#             print(url, text)
# ```

# %% [markdown]
# 提取分页的链接：

# %% [markdown]
# ```python
# lks2 = LinkExtractor(allow=r"beijing/a0_0msdgscncgpi1ltocsp\d+exx0")  # 只要在url中能匹配到正则的内容都会提取
# links = lks2.extract_links(reps)
# for link in links:
#     url = link.url
#     text = link.text
#     print(url, text)
# ```

# %% [markdown]
# CrawlSpider可以将链接提取器拿到的详情页和分页链接进行整合，提取数据。其是scrapy提供的一个爬虫，在`scrapy.Spider`的基础上进行了封装。
#
# 由于CrawlSpider做了高度的封装，它不好理解且灵活性可控性差，**不作为重点学习**，了解即可

# %% [markdown]
# ### 案例

# %% [markdown]
# **诗词名句网站**

# %% [markdown]
# 网址：https://www.shicimingjv.com/tangshi/

# %% [markdown]
# 创建爬虫：`scrapy genspider -t crawl tang shicimingjv.com`, 使用crawl模板创建spider。

# %% [markdown]
# 生成的爬虫代码：
# ```python
# import scrapy
# from scrapy.linkextractors import LinkExtractor
# from scrapy.spiders import CrawlSpider, Rule
#
#
# class TangSpider(CrawlSpider):
#     name = 'tang'
#     allowed_domains = ['shicimingjv.com']
#     start_urls = ['http://shicimingjv.com/']
#
#     rules = (
#         # 这里会自动提取链接，并自动发送请求。
#         Rule(LinkExtractor(allow=r'Items/'), callback='parse_item', follow=True),  # callback 是字符串，请求响应会自动执行parse_item. follow=True 表示是否将当前流程(也就是rule的流程)在走一遍，
#     )
#
#     def parse_item(self, response):
#         item = {}
#         #item['domain_id'] = response.xpath('//input[@id="sid"]/@value').get()
#         #item['name'] = response.xpath('//div[@id="name"]').get()
#         #item['description'] = response.xpath('//div[@id="description"]').get()
#         return item
#
# ```

# %% [markdown]
# **代码**

# %% [markdown]
# 获取一页的详情页和解析详情页的数据
# ```python
# import scrapy
# from scrapy.linkextractors import LinkExtractor
# from scrapy.spiders import CrawlSpider, Rule
#
#
# class TangSpider(CrawlSpider):
#     name = 'tang'
#     allowed_domains = ['shicimingjv.com']
#     start_urls = ['https://www.shicimingjv.com/tangshi/']
#
#     rules = (
#         Rule(LinkExtractor(restrict_xpaths="//h3[@class='item-title']/a"), callback='parse_item'),
#     )
#
#     def parse_item(self, resp):
#         print(resp.url)
#         title = resp.xpath("//h1[@class='mp3']/text()").extract_first()
#         print(title)
#
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# rules的执行源码：就是遍历rules，拿到所有的链接，每个链接发送请求，执行callback指定的函数。

# %% [markdown]
# 添加分页的逻辑

# %% [markdown]
# ```python
# import scrapy
# from scrapy.linkextractors import LinkExtractor
# from scrapy.spiders import CrawlSpider, Rule
#
#
# class TangSpider(CrawlSpider):
#     name = 'tang'
#     allowed_domains = ['shicimingjv.com']
#     start_urls = ['https://www.shicimingjv.com/tangshi/']
#
#     rules = (
#         Rule(LinkExtractor(restrict_xpaths="//h3[@class='item-title']/a"), callback='parse_item'),  # 可以对于当前页中的其他地方进行设定规则拿到详情页解析。
#         Rule(LinkExtractor(restrict_xpaths="//ul[@class='pagination']/li/a"), follow=True),  # 分页，follow表示每个请求重来rules的逻辑
#         # 在callback中提取数据，分页只是访问了页面。没有提取任何数据，所以callback可以不写。follow=True， 将rules的流程在走一遍.
#         # 也就是说，在分页的Rule执行时，拿到了几个页面的地址，在访问那几个页面的地址，返回响应时，会重新走一遍rules中的Rule，
#     )
#
#     def parse_item(self, resp):
#         print(resp.url)
#         title = resp.xpath("//h1[@class='mp3']/text()").extract_first()
#         print(title)
#
# ```

# %% [markdown]
# 执行逻辑：
# 1. 访问start_urls的地址，拿到响应
# 2. 开始执行rules指定的规则
#     - 第一个Rule，在start_urls响应对象中，拿到指定详情页规则的url，并自动发送详情页的请求，该请求响应回来后执行parse_item方法。
#     - 第二个Rule，在start_urls响应对象中，拿到指定分页规则的url，并自动发送分页url的请求，由于设置了follow=True并且没有设置callback，当一个分页请求的响应对象回来后，在分页请求的响应对象中，再走一遍rules中指定的Rule。
# 3. 再走Rule中的规则
#     - 第一个Rule，在分页请求的响应对象中，拿到指定详情页规则的url，并自动发送详情页的请求，该请求响应回来后执行parse_item方法。
#     - 第二个Rule，在分页请求的响应对象中，拿到指定分页规则的url，并自动发送分页url的请求，由于设置了follow=True并且没有设置callback，当一个分页请求的响应对象回来后，在分页请求的响应对象中，再走一遍rules中指定的Rule。
#
# 每个分页请求回来后，都会走rules中指定的规则，所以全站每一页的数据都拿到了。

# %% [markdown]
# 文档：http://t.zoukankan.com/xiaowenshu-p-10450848.html

# %% [markdown]
# # 调试

# %% [markdown]
# 使用鼠标点击调试

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 使用快捷键调试
